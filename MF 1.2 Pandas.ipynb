# %%
import pandas as pd

# %%
s1 = pd.Series(data=[1,2,3,4,5], index=['a','b','c','d','e'])

# %%
s2 = pd.Series(data=[11,22,33,44,55], index=['a','b','c','d','e'])

# %%
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s2
# Out:
# a    11
# b    22
# c    33
# d    44
# e    55
# dtype: int64

# %%
s1['a':'d']
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s1[0:3]
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
pd.DataFrame({'A':s1,'B':s2},index=['a','c'])
# Out:
#    A   B
# a  1  11
# c  3  33

# %%
pd.DataFrame([s1,s2])
# Out:
#     a   b   c   d   e
# 0   1   2   3   4   5
# 1  11  22  33  44  55

# %%
s3 = pd.Series(data=[111,222],index=['a','b'])

# %%
df = pd.DataFrame({'A':s1,'B':s2,'C':s3})

# %%
df['A']
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: A, dtype: int64

# %%
df[['A','B']]
# Out:
#    A   B
# a  1  11
# b  2  22
# c  3  33
# d  4  44
# e  5  55

# %%
emp_data = pd.read_csv(r'C:/Users/awant/workspace/machine-learning/Data/HR_comma_sep.csv.txt')

# %%
emp_data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
emp_data.rename(columns={'sales':'dept'}, inplace=True)

# %%
emp_data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years   dept  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
emp_data.dept.value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: dept, dtype: int64

# %%
emp_data.salary.value_counts()
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
emp_data.satisfaction_level.mean()
# Out:
# 0.6128335222348166

# %%
emp_data.satisfaction_level.median()
# Out:
# 0.64

# %%
emp_data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years   dept  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
emp_data.iloc[3:5]
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years   dept  \
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#   salary
# 3    low
# 4    low

# %%
cols = ['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship'
        ,'race','sex','capital-gain','capital-loss','hours-per-week','native-country','Salary']

df = pd.read_csv('Data/adult.data.txt',header=None,names=cols)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# Salary            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
target_data = df['Salary']

# %%
feature_data = df.drop(['Salary'],axis=1)

# %%
df2 = df.set_index('age')

# %%
df2.loc[20]
# Out:
#         workclass  fnlwgt      education  education-num  \
# age
# 20        Private  266015   Some-college             10
# 20        Private  188300   Some-college             10
# 20        Private  111697   Some-college             10
# 20        Private   34310   Some-college             10
# 20              ?  119156   Some-college             10
# 20        Private  117789        HS-grad              9
# 20      Local-gov  350845   Some-college             10
# 20              ?  137300        HS-grad              9
# 20        Private  416103   Some-college             10
# 20        Private   61777   Some-college             10
# 20        Private  298227   Some-college             10
# 20        Private  146538        HS-grad              9
# 20        Private  262749   Some-college             10
# 20              ?  214635   Some-college             10
# 20        Private   27337        HS-grad              9
# 20        Private  130959   Some-college             10
# ...

# %%
df[(df.age >= 30) & (df['marital-status'] == 'Married-civ-spouse')]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, Salary]
# Index: []

# %%
df.iloc[0]['marital-status']
# Out:
# ' Never-married'

# %%
df['marital-status'] = df['marital-status'].str.strip()

# %%
df.iloc[0]['marital-status']
# Out:
# 'Never-married'

# %%
df.workclass.str.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# Salary            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df[(df.age >= 30) & (df['marital-status'] == 'Married-civ-spouse')]
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 3       53            Private  234721           11th              7
# 5       37            Private  284582        Masters             14
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 14      40            Private  121772      Assoc-voc             11
# 15      34            Private  245487        7th-8th              4
# 18      38            Private   28887           11th              7
# 20      40            Private  193524      Doctorate             16
# 22      35        Federal-gov   76845            9th              5
# 23      43            Private  117037           11th              7
# ...

# %%
df.iat[0,2]
# Out:
# 77516

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#        marital-status          occupation    relationship    race      sex  \
# 0       Never-married        Adm-clerical   Not-in-family   White     Male
# 1  Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2            Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3  Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4  Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.at[1,'workclass']
# Out:
# ' Self-emp-not-inc'

# %%
df.drop([0,1,2],inplace=True)
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 12      23            Private  122272      Bachelors             13
# ...

# %%
df = pd.DataFrame({'A':[1,1,3,4,5,1], 'B':[1,1,3,7,8,1], 'C':[3,1,1,6,7,1]})

# %%
df
# Out:
#    A  B  C
# 0  1  1  3
# 1  1  1  1
# 2  3  3  1
# 3  4  7  6
# 4  5  8  7
# 5  1  1  1

# %%
df.drop_duplicates(subset=['A','B'],keep='last')
# Out:
#    A  B  C
# 2  3  3  1
# 3  4  7  6
# 4  5  8  7
# 5  1  1  1

# %%
titanic_data = pd.read_csv('https://raw.githubusercontent.com/zekelabs/machine-learning-for-beginners/master/data/titanic-train.csv')

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
titanic_data[titanic_data.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
titanic_data[titanic_data.Age.notnull()].Age.median()
# Out:
# 28.0

# %%
titanic_data.Age = titanic_data.Age.fillna(28)

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

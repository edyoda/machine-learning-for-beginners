# %%
from sklearn.datasets import make_circles

# %%
X,Y = make_circles(n_samples=1000, noise=0.05)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.scatter(X[:,0],X[:,1],c=Y)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# 1. Split Data
# 2. Use Logistic Regression in model training
# 3. Predict type

# %%
from sklearn.model_selection import train_test_split

# %%
trainX,testX, trainY,testY = train_test_split(iris.data,iris.target)

# %%
lr = LogisticRegression(C= , penalty=)

# %%
lr.fit(trainX,trainY)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
lr.score(testX,testY)
# Out:
# 0.9210526315789473

# %%
lr.predict([[1,1,1,1],[2,2,2,2]])
# Out:
# array([2, 2])

# %%
lr.classes_
# Out:
# array([0, 1, 2])

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
lr.predict(testX)
# Out:
# array([1, 0, 1, 0, 2, 0, 1, 2, 2, 2, 1, 2, 1, 2, 2, 1, 1, 1, 0, 1, 2, 0,
#        2, 1, 1, 2, 0, 1, 2, 0, 0, 0, 2, 1, 2, 1, 2, 2])

# %%
lr.predict_proba(testX)
# Out:
# array([[1.23263103e-01, 7.07822296e-01, 1.68914601e-01],
#        [8.84696637e-01, 1.14996954e-01, 3.06409129e-04],
#        [7.72405531e-02, 5.65742046e-01, 3.57017401e-01],
#        [9.47781049e-01, 5.21867268e-02, 3.22244206e-05],
#        [3.92325062e-04, 3.38957240e-01, 6.60650435e-01],
#        [9.52714834e-01, 4.72702993e-02, 1.48665347e-05],
#        [5.44607688e-02, 6.10189333e-01, 3.35349898e-01],
#        [1.15720064e-03, 1.68262906e-01, 8.30579893e-01],
#        [2.72071752e-04, 4.19857173e-01, 5.79870755e-01],
#        [1.90386733e-02, 3.75216807e-01, 6.05744520e-01],
#        [3.15346181e-02, 5.90710913e-01, 3.77754469e-01],
#        [9.40132317e-04, 3.89634553e-01, 6.09425315e-01],
#        [5.35635561e-03, 5.69465742e-01, 4.25177902e-01],
#        [5.97953151e-04, 2.19879716e-01, 7.79522331e-01],
#        [5.80272859e-04, 3.23964377e-01, 6.75455350e-01],
#        [8.15528195e-02, 7.24915451e-01, 1.93531729e-01],
# ...

# %%
y_pred = lr.predict(testX)

# %%
from sklearn.metrics import confusion_matrix,precision_score,re

# %%
confusion_matrix(testY,y_pred)
# Out:
# array([[ 9,  0,  0],
#        [ 0, 14,  3],
#        [ 0,  0, 12]], dtype=int64)

# %%
import seaborn as sns; sns.set()

# %%
sns.heatmap(confusion_matrix(testY,y_pred),annot=True)

# %%
help(LogisticRegression)
# Out:
# Help on class LogisticRegression in module sklearn.linear_model.logistic:
#
# class LogisticRegression(sklearn.base.BaseEstimator, sklearn.linear_model.base.LinearClassifierMixin, sklearn.linear_model.base.SparseCoefMixin)
#  |  Logistic Regression (aka logit, MaxEnt) classifier.
#  |
#  |  In the multiclass case, the training algorithm uses the one-vs-rest (OvR)
#  |  scheme if the 'multi_class' option is set to 'ovr', and uses the cross-
#  |  entropy loss if the 'multi_class' option is set to 'multinomial'.
#  |  (Currently the 'multinomial' option is supported only by the 'lbfgs',
#  |  'sag' and 'newton-cg' solvers.)
#  |
#  |  This class implements regularized logistic regression using the
#  |  'liblinear' library, 'newton-cg', 'sag' and 'lbfgs' solvers. It can handle
#  |  both dense and sparse input. Use C-ordered arrays or CSR matrices
#  |  containing 64-bit floats for optimal performance; any other input format
#  |  will be converted (and copied).
#  |
# ...

# %%
precision_score(testY,y_pred,average='macro')
# Out:
# 0.9333333333333332

# %%
from sklearn.externals import joblib

# %%
joblib.dump(lr,'model.pkl')
# Out:
# ['model.pkl']

# %%
l = joblib.load('model.pkl')

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgd = SGDClassifier()

# %%
sgd.pa

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3'],
                     'C': ['C0', 'C1', 'C2', 'C3'],
                     'D': ['D0', 'D1', 'D2', 'D3']},
                     index=[0, 1, 2, 3])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'],
                    'E': ['D8', 'D9', 'D10', 'D11']},
                    )

# %%
df3
# Out:
#      A    B    C    E
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
pd.concat([df1,df2])
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %% [markdown]
# ### Vertical Stacking

# %%
pd.concat([df1,df3], ignore_index=True,axis=0)
# Out:
#      A    B    C    D    E
# 0   A0   B0   C0   D0  NaN
# 1   A1   B1   C1   D1  NaN
# 2   A2   B2   C2   D2  NaN
# 3   A3   B3   C3   D3  NaN
# 4   A8   B8   C8  NaN   D8
# 5   A9   B9   C9  NaN   D9
# 6  A10  B10  C10  NaN  D10
# 7  A11  B11  C11  NaN  D11

# %% [markdown]
# ### Horizontal Stacking

# %%
pd.concat([df1,df3], ignore_index=True,axis=1)
# Out:
#     0   1   2   3    4    5    6    7
# 0  A0  B0  C0  D0   A8   B8   C8   D8
# 1  A1  B1  C1  D1   A9   B9   C9   D9
# 2  A2  B2  C2  D2  A10  B10  C10  D10
# 3  A3  B3  C3  D3  A11  B11  C11  D11

# %% [markdown]
# ### Merge

# %%
pd.concat([df1,df3],join="inner",axis=0)
# Out:
#      A    B    C
# 0   A0   B0   C0
# 1   A1   B1   C1
# 2   A2   B2   C2
# 3   A3   B3   C3
# 0   A8   B8   C8
# 1   A9   B9   C9
# 2  A10  B10  C10
# 3  A11  B11  C11

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df3
# Out:
#      A    B    C    E
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %% [markdown]
# ### Merge

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K4'],
                         'A': ['A0', 'A1', 'A2', 'A3'],
                         'B': ['B0', 'B1', 'B2', 'B3']})

right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                         'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#     A   B key
# 0  A0  B0  K0
# 1  A1  B1  K1
# 2  A2  B2  K2
# 3  A3  B3  K4

# %%
right
# Out:
#     C   D key
# 0  C0  D0  K0
# 1  C1  D1  K1
# 2  C2  D2  K2
# 3  C3  D3  K3

# %%
pd.concat([left,right])
# Out:
#      A    B    C    D key
# 0   A0   B0  NaN  NaN  K0
# 1   A1   B1  NaN  NaN  K1
# 2   A2   B2  NaN  NaN  K2
# 3   A3   B3  NaN  NaN  K4
# 0  NaN  NaN   C0   D0  K0
# 1  NaN  NaN   C1   D1  K1
# 2  NaN  NaN   C2   D2  K2
# 3  NaN  NaN   C3   D3  K3

# %%
left.merge(right, how='outer',on='key')
# Out:
#      A    B key    C    D
# 0   A0   B0  K0   C0   D0
# 1   A1   B1  K1   C1   D1
# 2   A2   B2  K2   C2   D2
# 3   A3   B3  K4  NaN  NaN
# 4  NaN  NaN  K3   C3   D3

# %%
left.merge(right, how='inner',on='key')
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K2  C2  D2

# %%
left = pd.DataFrame({ 'key1': ['K0', 'K0', 'K1', 'K2'],
                      'key2': ['K0', 'K1', 'K0', 'K1'],
                         'A': ['A0', 'A1', 'A2', 'A3'],
                         'B': ['B0', 'B1', 'B2', 'B3']})
    

right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0'],
                      'C':    ['C0', 'C1', 'C2', 'C3'],
                         'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#     A   B key1 key2
# 0  A0  B0   K0   K0
# 1  A1  B1   K0   K1
# 2  A2  B2   K1   K0
# 3  A3  B3   K2   K1

# %%
right
# Out:
#     C   D key1 key2
# 0  C0  D0   K0   K0
# 1  C1  D1   K1   K0
# 2  C2  D2   K1   K0
# 3  C3  D3   K2   K0

# %%
left.merge(right,on=['key1','key2'])
# Out:
#     A   B key1 key2   C   D
# 0  A0  B0   K0   K0  C0  D0
# 1  A2  B2   K1   K0  C1  D1
# 2  A2  B2   K1   K0  C2  D2

# %%
left.merge(right, how="outer",indicator=True)
# Out:
#      A    B key1 key2    C    D      _merge
# 0   A0   B0   K0   K0   C0   D0        both
# 1   A1   B1   K0   K1  NaN  NaN   left_only
# 2   A2   B2   K1   K0   C1   D1        both
# 3   A2   B2   K1   K0   C2   D2        both
# 4   A3   B3   K2   K1  NaN  NaN   left_only
# 5  NaN  NaN   K2   K0   C3   D3  right_only

# %% [markdown]
# ### Load West Bengal Data

# %%
wb_data = pd.read_csv('Data/company_master_data_upto_Mar_2015_West_Bengal.csv')

# %%
tn_data = pd.read_csv('Data/company_master_data_upto_Mar_2015_Tamil_Nadu.csv', encoding="latin-1")

# %%
wb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185052 entries, 0 to 185051
# Data columns (total 13 columns):
# CORPORATE_IDENTIFICATION_NUMBER    185052 non-null object
# DATE_OF_REGISTRATION               185051 non-null object
# COMPANY_NAME                       185052 non-null object
# COMPANY_STATUS                     185052 non-null object
# COMPANY_CLASS                      185052 non-null object
# COMPANY_CATEGORY                   185052 non-null object
# AUTHORIZED_CAPITAL                 184514 non-null object
# PAIDUP_CAPITAL                     182547 non-null object
# REGISTERED_STATE                   185052 non-null object
# REGISTRAR_OF_COMPANIES             185052 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY        184374 non-null object
# REGISTERED_OFFICE_ADDRESS          185052 non-null object
# SUB_CATEGORY                       185052 non-null object
# dtypes: object(13)
# memory usage: 18.4+ MB

# %%
tn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114428 entries, 0 to 114427
# Data columns (total 13 columns):
# CORPORATE_IDENTIFICATION_NUMBER    114428 non-null object
# DATE_OF_REGISTRATION               114428 non-null object
# COMPANY_NAME                       114428 non-null object
# COMPANY_STATUS                     114428 non-null object
# COMPANY_CLASS                      114428 non-null object
# COMPANY_CATEGORY                   114428 non-null object
#  AUTHORIZED_CAPITAL                113978 non-null object
#  PAIDUP_CAPITAL                    97473 non-null object
# REGISTERED_STATE                   114428 non-null object
# REGISTRAR_OF_COMPANIES             114428 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY        111841 non-null object
# REGISTERED_OFFICE_ADDRESS          114428 non-null object
# SUB_CATEGORY                       114428 non-null object
# dtypes: object(13)
# memory usage: 11.3+ MB

# %%
tn_data.columns = list(map(lambda x: x.strip(),tn_data.columns.tolist()))

# %%
tn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114428 entries, 0 to 114427
# Data columns (total 13 columns):
# CORPORATE_IDENTIFICATION_NUMBER    114428 non-null object
# DATE_OF_REGISTRATION               114428 non-null object
# COMPANY_NAME                       114428 non-null object
# COMPANY_STATUS                     114428 non-null object
# COMPANY_CLASS                      114428 non-null object
# COMPANY_CATEGORY                   114428 non-null object
# AUTHORIZED_CAPITAL                 113978 non-null object
# PAIDUP_CAPITAL                     97473 non-null object
# REGISTERED_STATE                   114428 non-null object
# REGISTRAR_OF_COMPANIES             114428 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY        111841 non-null object
# REGISTERED_OFFICE_ADDRESS          114428 non-null object
# SUB_CATEGORY                       114428 non-null object
# dtypes: object(13)
# memory usage: 11.3+ MB

# %%
tn_data.head()
# Out:
#   CORPORATE_IDENTIFICATION_NUMBER DATE_OF_REGISTRATION  \
# 0                            IDIB            5-01-1955
# 1                            IOBA            5-01-1955
# 2           L01115TN1956PLC003435           14-09-1956
# 3           L01116TN1995PLC032153            6-07-1995
# 4           L01117TZ1943PLC000117           21-04-1943
#
#                                 COMPANY_NAME COMPANY_STATUS COMPANY_CLASS  \
# 0                                INDIAN BANK         ACTIVE        Public
# 1                       INDIAN OVERSEAS BANK         ACTIVE        Public
# 2               SRI SARVARAYA SUGARS LIMITED         ACTIVE        Public
# 3  SHARAVANA ESTATES AND PLANTATIONS LIMITED         ACTIVE        Public
# 4         NEELAMALAI AGRO INDUSTRIES LIMITED         ACTIVE        Public
#
#             COMPANY_CATEGORY AUTHORIZED_CAPITAL PAIDUP_CAPITAL  \
# 0  Company Limited by Shares  30,000,000,000.00            NaN
# ...

# %%
wb_tn = pd.concat([wb_data,tn_data])

# %%
wb_tn.head()
# Out:
#   CORPORATE_IDENTIFICATION_NUMBER DATE_OF_REGISTRATION  \
# 0                            ALLA            5-01-1955
# 1           L01111WB1997PLC085164           13-08-1997
# 2           L01113WB1988PLC043816           19-02-1988
# 3           L01113WB1990PLC050020           12-10-1990
# 4           L01117WB1983PLC036230           22-04-1983
#
#                    COMPANY_NAME COMPANY_STATUS COMPANY_CLASS  \
# 0                ALLAHABAD BANK         ACTIVE        Public
# 1    REAL TOUCH FINANCE LIMITED         ACTIVE        Public
# 2  EASTERN FIBRE INDUSTRIES LTD         ACTIVE        Public
# 3     ACKNIT INDUSTRIES LIMITED         ACTIVE        Public
# 4        NONSTOP PLANTATION LTD         ACTIVE        Public
#
#             COMPANY_CATEGORY AUTHORIZED_CAPITAL  PAIDUP_CAPITAL  \
# 0  Company Limited by Shares  30,000,000,000.00             NaN
# 1  Company Limited by Shares     162,000,000.00  126,926,900.00
# 2  Company Limited by Shares      30,000,000.00   29,440,500.00
# ...

# %%
wb_tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 299480 entries, 0 to 114427
# Data columns (total 13 columns):
# CORPORATE_IDENTIFICATION_NUMBER    299480 non-null object
# DATE_OF_REGISTRATION               299479 non-null object
# COMPANY_NAME                       299480 non-null object
# COMPANY_STATUS                     299480 non-null object
# COMPANY_CLASS                      299480 non-null object
# COMPANY_CATEGORY                   299480 non-null object
# AUTHORIZED_CAPITAL                 298492 non-null object
# PAIDUP_CAPITAL                     280020 non-null object
# REGISTERED_STATE                   299480 non-null object
# REGISTRAR_OF_COMPANIES             299480 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY        296215 non-null object
# REGISTERED_OFFICE_ADDRESS          299480 non-null object
# SUB_CATEGORY                       299480 non-null object
# dtypes: object(13)
# memory usage: 32.0+ MB

# %%
wb_tn.PRINCIPAL_BUSINESS_ACTIVITY.value_counts()
# Out:
# Trading                                                                                            79121
# Business Services                                                                                  51932
# Real Estate and Renting                                                                            23633
# Finance                                                                                            22772
# Manufacturing (Metals & Chemicals, and products thereof)                                           22368
# Construction                                                                                       21792
# Manufacturing (Machinery & Equipments)                                                             13817
# Community, personal & Social Services                                                              11655
# Manufacturing (Textiles)                                                                           10574
# ...

# %%
wb_data_trading = wb_data.loc[wb_data.PRINCIPAL_BUSINESS_ACTIVITY == 'Trading']

# %%
tn_data_trading = tn_data.loc[tn_data.PRINCIPAL_BUSINESS_ACTIVITY == 'Trading']

# %%
tn_data_trading.describe()
# Out:
#        CORPORATE_IDENTIFICATION_NUMBER DATE_OF_REGISTRATION  \
# count                            12847                12847
# unique                           12847                 5935
# top              U52322TZ1988PTC002262           21-04-2004
# freq                                 1                   13
#
#                                              COMPANY_NAME COMPANY_STATUS  \
# count                                               12847          12847
# unique                                              12842             12
# top     NORTH AMERICAN TRADING COMPANY (INDIA) PRIVATE...         ACTIVE
# freq                                                    2           7293
#
#        COMPANY_CLASS           COMPANY_CATEGORY AUTHORIZED_CAPITAL  \
# count          12847                      12847              12833
# unique             3                          2                339
# top          Private  Company Limited by Shares         100,000.00
# ...

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                     index=['K0', 'K1', 'K2'])

# %%
right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                      'D': ['D0', 'D2', 'D3']},
                     index=['K0', 'K2', 'K3'])

# %%
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
left.merge(right,left_index=True,right_index=True)
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %%
left.join(right,how="outer")
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
train = pd.read_csv('Data/rossman/train.csv')
# Out:
# C:\Users\awant\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
store = pd.read_csv('Data/rossman/store.csv')

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
train.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
train.merge(store,on="Store")
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            1          4  2015-07-30   5020        546     1      1
# 2            1          3  2015-07-29   4782        523     1      1
# 3            1          2  2015-07-28   5011        560     1      1
# 4            1          1  2015-07-27   6102        612     1      1
# 5            1          7  2015-07-26      0          0     0      0
# 6            1          6  2015-07-25   4364        500     1      0
# 7            1          5  2015-07-24   3706        459     1      0
# 8            1          4  2015-07-23   3769        503     1      0
# 9            1          3  2015-07-22   3464        463     1      0
# 10           1          2  2015-07-21   3558        469     1      0
# 11           1          1  2015-07-20   4395        526     1      0
# 12           1          7  2015-07-19      0          0     0      0
# ...

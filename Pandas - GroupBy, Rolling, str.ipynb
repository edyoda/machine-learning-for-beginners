# %%
import pandas as pd

# %%
wb_data = pd.read_csv('Data/company_master_data_upto_Mar_2015_West_Bengal.csv')

# %%
wb_data.head()
# Out:
#   CORPORATE_IDENTIFICATION_NUMBER DATE_OF_REGISTRATION  \
# 0                            ALLA            5-01-1955
# 1           L01111WB1997PLC085164           13-08-1997
# 2           L01113WB1988PLC043816           19-02-1988
# 3           L01113WB1990PLC050020           12-10-1990
# 4           L01117WB1983PLC036230           22-04-1983
#
#                    COMPANY_NAME COMPANY_STATUS COMPANY_CLASS  \
# 0                ALLAHABAD BANK         ACTIVE        Public
# 1    REAL TOUCH FINANCE LIMITED         ACTIVE        Public
# 2  EASTERN FIBRE INDUSTRIES LTD         ACTIVE        Public
# 3     ACKNIT INDUSTRIES LIMITED         ACTIVE        Public
# 4        NONSTOP PLANTATION LTD         ACTIVE        Public
#
#             COMPANY_CATEGORY AUTHORIZED_CAPITAL  PAIDUP_CAPITAL  \
# 0  Company Limited by Shares  30,000,000,000.00             NaN
# 1  Company Limited by Shares     162,000,000.00  126,926,900.00
# 2  Company Limited by Shares      30,000,000.00   29,440,500.00
# ...

# %%
wb_data.groupby('COMPANY_STATUS').groups.keys()
# Out:
# dict_keys(['ACTIVE', 'ACTIVE IN PROGRESS', 'AMALGAMATED', 'CONVERTED TO LLP', 'CONVERTED TO LLP AND DISSOLVED', 'DISSOLVED', 'DORMANT', 'Dormant under section 455 of Companies Act, 2013', 'LIQUIDATED', 'STRIKE OFF', 'UNDER LIQUIDATION', 'UNDER PROCESS OF STRIKING OFF'])

# %%
gbdata = wb_data.groupby('COMPANY_STATUS')

# %%
gbdata.get_group('ACTIVE')
# Out:
#        CORPORATE_IDENTIFICATION_NUMBER DATE_OF_REGISTRATION  \
# 0                                 ALLA            5-01-1955
# 1                L01111WB1997PLC085164           13-08-1997
# 2                L01113WB1988PLC043816           19-02-1988
# 3                L01113WB1990PLC050020           12-10-1990
# 4                L01117WB1983PLC036230           22-04-1983
# 5                L01117WB1983PLC036337           23-05-1983
# 7                L01119WB1992PLC055908            9-07-1992
# 8                L01122WB1953PLC021090           13-06-1953
# 11               L01131WB1952PLC020342            3-04-1952
# 14               L01132WB1874PLC000281           05-03-1874
# 15               L01132WB1885PLC000505           03-01-1885
# 16               L01132WB1889PLC000576           24-06-1889
# 17               L01132WB1891PLC000687           06-05-1891
# 18               L01132WB1893PLC000742           04-02-1893
# 19               L01132WB1900PLC000292            7-08-1900
# ...

# %%
gbdata.size()
# Out:
# COMPANY_STATUS
# ACTIVE                                              137172
# ACTIVE IN PROGRESS                                       3
# AMALGAMATED                                           3952
# CONVERTED TO LLP                                       228
# CONVERTED TO LLP AND DISSOLVED                         457
# DISSOLVED                                              613
# DORMANT                                                790
# Dormant under section 455 of Companies Act, 2013        21
# LIQUIDATED                                              26
# STRIKE OFF                                           38685
# UNDER LIQUIDATION                                      653
# UNDER PROCESS OF STRIKING OFF                         2452
# dtype: int64

# %%
wb_data.SUB_CATEGORY.value_counts()
# Out:
# Indian Non-Government Company        184045
# Others                                  444
# Guarantee and association Company       195
# Company licensed under Section25        174
# Subsidiary of Foreign Company            79
# State Government Company                 77
# Union Government Company                 38
# Name: SUB_CATEGORY, dtype: int64

# %%
df = pd.DataFrame({'A':[1,2,3,4,1,6],'B':[1,2,3,4,1,6],'C':[5,6,7,8,9,3]})
df
# Out:
#    A  B  C
# 0  1  1  5
# 1  2  2  6
# 2  3  3  7
# 3  4  4  8
# 4  1  1  9
# 5  6  6  3

# %%
df.groupby(('A','B')).groups
# Out:
# {(1, 1): Int64Index([0, 4], dtype='int64'),
#  (2, 2): Int64Index([1], dtype='int64'),
#  (3, 3): Int64Index([2], dtype='int64'),
#  (4, 4): Int64Index([3], dtype='int64'),
#  (6, 6): Int64Index([5], dtype='int64')}

# %%
df_gb = df.groupby(('A','B'))

# %%
import numpy as np
df_gb.agg({'C':lambda x:sum(x)})
# Out:
#       C
# A B
# 1 1  14
# 2 2   6
# 3 3   7
# 4 4   8
# 6 6   3

# %%
# def f(x):
#     res = 0
#     for i in x:
#         res += x
#     return res

df_gb.agg({'C':'mean'})
# Out:
#      C
# A B
# 1 1  7
# 2 2  6
# 3 3  7
# 4 4  8
# 6 6  3

# %%
df_gb.describe()
# Out:
#         C
#     count mean       std  min  25%  50%  75%  max
# A B
# 1 1   2.0  7.0  2.828427  5.0  6.0  7.0  8.0  9.0
# 2 2   1.0  6.0       NaN  6.0  6.0  6.0  6.0  6.0
# 3 3   1.0  7.0       NaN  7.0  7.0  7.0  7.0  7.0
# 4 4   1.0  8.0       NaN  8.0  8.0  8.0  8.0  8.0
# 6 6   1.0  3.0       NaN  3.0  3.0  3.0  3.0  3.0

# %%
titanic_data = pd.read_csv('https://raw.githubusercontent.com/zekelabs/machine-learning-for-beginners/master/data/titanic-train.csv', index_col='PassengerId')

# %%
titanic_data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
titanic_data.groupby(('Sex','Pclass')).describe()
# Out:
#                  Age                                                         \
#                count       mean        std   min     25%   50%    75%   max
# Sex    Pclass
# female 1        85.0  34.611765  13.612052  2.00  23.000  35.0  44.00  63.0
#        2        74.0  28.722973  12.872702  2.00  22.250  28.0  36.00  57.0
#        3       102.0  21.750000  12.729964  0.75  14.125  21.5  29.75  63.0
# male   1       101.0  41.281386  15.139570  0.92  30.000  40.0  51.00  80.0
#        2        99.0  30.740707  14.793894  0.67  23.000  30.0  36.75  70.0
#        3       253.0  26.507589  12.159514  0.42  20.000  25.0  33.00  74.0
#
#                 Fare             ...  SibSp      Survived                      \
#                count        mean ...    75%  max    count      mean       std
# Sex    Pclass                    ...
# female 1        94.0  106.125798 ...    1.0  3.0     94.0  0.968085  0.176716
# ...

# %%
df
# Out:
#    A  B  C
# 0  1  1  5
# 1  2  2  6
# 2  3  3  7
# 3  4  4  8
# 4  1  1  9
# 5  6  6  3

# %%
df.rolling(window=3, min_periods=1).mean()
# Out:
#           A         B         C
# 0  1.000000  1.000000  5.000000
# 1  1.500000  1.500000  5.500000
# 2  2.000000  2.000000  6.000000
# 3  3.000000  3.000000  7.000000
# 4  2.666667  2.666667  8.000000
# 5  3.666667  3.666667  6.666667

# %%
sales_data = pd.read_csv('Data/rossman/train.csv', parse_dates=['Date'])
# Out:
# C:\Users\awant\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
# Store            1017209 non-null int64
# DayOfWeek        1017209 non-null int64
# Date             1017209 non-null datetime64[ns]
# Sales            1017209 non-null int64
# Customers        1017209 non-null int64
# Open             1017209 non-null int64
# Promo            1017209 non-null int64
# StateHoliday     1017209 non-null object
# SchoolHoliday    1017209 non-null int64
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 69.8+ MB

# %%
sales_data.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
perdaysales = sales_data.groupby('Date').agg({'Sales':'sum'})

# %%
perweeksales = perdaysales.rolling(window=7,min_periods=1).sum()

# %%
perweeksales.sort_values('Sales',ascending=False)
# Out:
#                  Sales
# Date
# 2013-12-22  75371329.0
# 2013-12-21  75321382.0
# 2013-12-23  74097837.0
# 2013-12-20  73094261.0
# 2013-12-19  68772082.0
# 2013-12-24  66276652.0
# 2013-12-18  64552007.0
# 2013-12-05  62026283.0
# 2013-12-06  61654489.0
# 2013-12-07  60271152.0
# 2013-12-08  60241244.0
# 2015-04-02  60230187.0
# 2014-12-21  59780187.0
# 2014-12-20  59739609.0
# 2013-12-17  59726943.0
# 2013-12-04  58991731.0
# 2014-12-23  58745511.0
# 2014-12-22  58654447.0
# 2014-12-19  58562424.0
# 2014-04-17  56273595.0
# 2015-07-03  56167940.0
# 2015-04-04  55932116.0
# 2015-04-05  55923085.0
# 2014-06-05  55873029.0
# 2015-07-05  55690481.0
# 2015-07-04  55683902.0
# 2013-03-28  55655685.0
# 2014-12-18  55545146.0
# 2013-12-03  55513279.0
# 2015-04-01  55192474.0
# ...                ...
# 2014-11-01  32077170.0
# 2014-11-02  32071552.0
# 2014-07-26  31842115.0
# 2014-07-27  31838661.0
# 2014-10-17  31829873.0
# 2014-09-25  31738845.0
# 2014-04-27  31657654.0
# ...

# %%
perweeksales['2013'].sum()
# Out:
# Sales    1.600435e+10
# dtype: float64

# %%
perweeksales['2014'].sum()
# Out:
# Sales    1.527827e+10
# dtype: float64

# %%
perweeksales['2015'].sum()
# Out:
# Sales    9.641947e+09
# dtype: float64

# %% [markdown]
# ### Handling strings in Pandas

# %%
titanic_data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
titanic_data['NameLen'] = titanic_data.Name.str.len()

# %%
titanic_data.NameLen.max()
# Out:
# 82

# %%
titanic_data[titanic_data.NameLen == 82]['Name']
# Out:
# PassengerId
# 308    Penasco y Castellana, Mrs. Victor de Satode (M...
# Name: Name, dtype: object

# %%
titanic_data['Gender'] = titanic_data.Name.str.contains('Mr\.')

# %%
titanic_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

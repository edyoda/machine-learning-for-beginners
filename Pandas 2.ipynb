# %%
import pandas as pd

# %%
wb_data = pd.read_csv('Data/company_master_data_upto_Mar_2015_West_Bengal.csv', index_col="CORPORATE_IDENTIFICATION_NUMBER",parse_dates=['DATE_OF_REGISTRATION'])

# %%
wb_data.head()
# Out:
#                                 DATE_OF_REGISTRATION  \
# CORPORATE_IDENTIFICATION_NUMBER
# ALLA                                      1955-05-01
# L01111WB1997PLC085164                     1997-08-13
# L01113WB1988PLC043816                     1988-02-19
# L01113WB1990PLC050020                     1990-12-10
# L01117WB1983PLC036230                     1983-04-22
#
#                                                  COMPANY_NAME COMPANY_STATUS  \
# CORPORATE_IDENTIFICATION_NUMBER
# ALLA                                           ALLAHABAD BANK         ACTIVE
# L01111WB1997PLC085164              REAL TOUCH FINANCE LIMITED         ACTIVE
# L01113WB1988PLC043816            EASTERN FIBRE INDUSTRIES LTD         ACTIVE
# L01113WB1990PLC050020               ACKNIT INDUSTRIES LIMITED         ACTIVE
# L01117WB1983PLC036230                  NONSTOP PLANTATION LTD         ACTIVE
#
#                                 COMPANY_CLASS           COMPANY_CATEGORY  \
# CORPORATE_IDENTIFICATION_NUMBER
# ...

# %%
wb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185052 entries, ALLA to UTBI
# Data columns (total 12 columns):
# DATE_OF_REGISTRATION           185051 non-null datetime64[ns]
# COMPANY_NAME                   185052 non-null object
# COMPANY_STATUS                 185052 non-null object
# COMPANY_CLASS                  185052 non-null object
# COMPANY_CATEGORY               185052 non-null object
# AUTHORIZED_CAPITAL             184514 non-null object
# PAIDUP_CAPITAL                 182547 non-null object
# REGISTERED_STATE               185052 non-null object
# REGISTRAR_OF_COMPANIES         185052 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY    184374 non-null object
# REGISTERED_OFFICE_ADDRESS      185052 non-null object
# SUB_CATEGORY                   185052 non-null object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 18.4+ MB

# %%
tn_data = pd.read_csv(r'Data/company_master_data_upto_Mar_2015_Tamil_Nadu.csv',index_col="CORPORATE_IDENTIFICATION_NUMBER",parse_dates=['DATE_OF_REGISTRATION'], encoding='latin-1')

# %%
tn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 114428 entries, IDIB to U99999TZ1996PTC007007
# Data columns (total 12 columns):
# DATE_OF_REGISTRATION           114428 non-null datetime64[ns]
# COMPANY_NAME                   114428 non-null object
# COMPANY_STATUS                 114428 non-null object
# COMPANY_CLASS                  114428 non-null object
# COMPANY_CATEGORY               114428 non-null object
#  AUTHORIZED_CAPITAL            113978 non-null object
#  PAIDUP_CAPITAL                97473 non-null object
# REGISTERED_STATE               114428 non-null object
# REGISTRAR_OF_COMPANIES         114428 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY    111841 non-null object
# REGISTERED_OFFICE_ADDRESS      114428 non-null object
# SUB_CATEGORY                   114428 non-null object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 11.3+ MB

# %%
tn_data.rename(columns={' PAIDUP_CAPITAL ':'PAIDUP_CAPITAL', ' AUTHORIZED_CAPITAL ':'AUTHORIZED_CAPITAL'}, inplace=True)

# %%
tn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 114428 entries, IDIB to U99999TZ1996PTC007007
# Data columns (total 12 columns):
# DATE_OF_REGISTRATION           114428 non-null datetime64[ns]
# COMPANY_NAME                   114428 non-null object
# COMPANY_STATUS                 114428 non-null object
# COMPANY_CLASS                  114428 non-null object
# COMPANY_CATEGORY               114428 non-null object
# AUTHORIZED_CAPITAL             113978 non-null object
# PAIDUP_CAPITAL                 97473 non-null object
# REGISTERED_STATE               114428 non-null object
# REGISTRAR_OF_COMPANIES         114428 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY    111841 non-null object
# REGISTERED_OFFICE_ADDRESS      114428 non-null object
# SUB_CATEGORY                   114428 non-null object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 11.3+ MB

# %%
tn_data.head()
# Out:
#                                 DATE_OF_REGISTRATION  \
# CORPORATE_IDENTIFICATION_NUMBER
# IDIB                                      1955-05-01
# IOBA                                      1955-05-01
# L01115TN1956PLC003435                     1956-09-14
# L01116TN1995PLC032153                     1995-06-07
# L01117TZ1943PLC000117                     1943-04-21
#
#                                                               COMPANY_NAME  \
# CORPORATE_IDENTIFICATION_NUMBER
# IDIB                                                           INDIAN BANK
# IOBA                                                  INDIAN OVERSEAS BANK
# L01115TN1956PLC003435                         SRI SARVARAYA SUGARS LIMITED
# L01116TN1995PLC032153            SHARAVANA ESTATES AND PLANTATIONS LIMITED
# L01117TZ1943PLC000117                   NEELAMALAI AGRO INDUSTRIES LIMITED
#
#                                 COMPANY_STATUS COMPANY_CLASS  \
# CORPORATE_IDENTIFICATION_NUMBER
# ...

# %%
tn_data.loc[:'L01117TZ1943PLC000117']
# Out:
#                                 DATE_OF_REGISTRATION  \
# CORPORATE_IDENTIFICATION_NUMBER
# IDIB                                      1955-05-01
# IOBA                                      1955-05-01
# L01115TN1956PLC003435                     1956-09-14
# L01116TN1995PLC032153                     1995-06-07
# L01117TZ1943PLC000117                     1943-04-21
#
#                                                               COMPANY_NAME  \
# CORPORATE_IDENTIFICATION_NUMBER
# IDIB                                                           INDIAN BANK
# IOBA                                                  INDIAN OVERSEAS BANK
# L01115TN1956PLC003435                         SRI SARVARAYA SUGARS LIMITED
# L01116TN1995PLC032153            SHARAVANA ESTATES AND PLANTATIONS LIMITED
# L01117TZ1943PLC000117                   NEELAMALAI AGRO INDUSTRIES LIMITED
#
#                                 COMPANY_STATUS COMPANY_CLASS  \
# CORPORATE_IDENTIFICATION_NUMBER
# ...

# %%
tn_data.iloc[:4]
# Out:
#                                 DATE_OF_REGISTRATION  \
# CORPORATE_IDENTIFICATION_NUMBER
# IDIB                                      1955-05-01
# IOBA                                      1955-05-01
# L01115TN1956PLC003435                     1956-09-14
# L01116TN1995PLC032153                     1995-06-07
#
#                                                               COMPANY_NAME  \
# CORPORATE_IDENTIFICATION_NUMBER
# IDIB                                                           INDIAN BANK
# IOBA                                                  INDIAN OVERSEAS BANK
# L01115TN1956PLC003435                         SRI SARVARAYA SUGARS LIMITED
# L01116TN1995PLC032153            SHARAVANA ESTATES AND PLANTATIONS LIMITED
#
#                                 COMPANY_STATUS COMPANY_CLASS  \
# CORPORATE_IDENTIFICATION_NUMBER
# IDIB                                    ACTIVE        Public
# IOBA                                    ACTIVE        Public
# ...

# %%
tn_data.COMPANY_STATUS.value_counts()
# Out:
# ACTIVE                                              69082
# STRIKE OFF                                          25382
# DORMANT                                             15405
# UNDER PROCESS OF STRIKING OFF                        1853
# AMALGAMATED                                          1057
# DISSOLVED                                             805
# LIQUIDATED                                            386
# UNDER LIQUIDATION                                     283
# CONVERTED TO LLP AND DISSOLVED                        103
# CONVERTED TO LLP                                       35
# ACTIVE IN PROGRESS                                     25
# Dormant under section 455 of Companies Act, 2013       12
# Name: COMPANY_STATUS, dtype: int64

# %%
tn_data.loc[tn_data.COMPANY_STATUS == 'ACTIVE IN PROGRESS']
# Out:
#                                 DATE_OF_REGISTRATION  \
# CORPORATE_IDENTIFICATION_NUMBER
# L51909TN1995PLC030554                     1995-03-17
# U01115TN1974SGC006552                     1974-02-22
# U01132TZ1986PTC001777                     1986-07-05
# U17121TZ2005PTC012171                     2005-09-21
# U18101TN1993PTC025305                     1993-06-23
# U19112TZ2003PTC010467                     2003-03-02
# U24231TN1984PTC010803                     1984-04-19
# U25209TN1994PTC029063                     1994-10-27
# U25209TN1995PLC032313                     1995-07-20
# U29309TN1997PTC038412                     1997-06-13
# U32301TN1989PTC017213                     1989-11-04
# U36939TN1993PTC025883                     1993-09-27
# U45201TN1995PTC031786                     1995-09-06
# U51505TN2005PTC056003                     2005-04-18
# U51909TN1997PTC038519                     1997-06-27
# U55101TZ1994PTC004907                     1994-09-03
# ...

# %%
tn_data.loc[(tn_data.COMPANY_STATUS == 'ACTIVE IN PROGRESS') & (tn_data.COMPANY_CLASS == 'Public')]
# Out:
#                                 DATE_OF_REGISTRATION  \
# CORPORATE_IDENTIFICATION_NUMBER
# L51909TN1995PLC030554                     1995-03-17
# U01115TN1974SGC006552                     1974-02-22
# U25209TN1995PLC032313                     1995-07-20
# U65991TN1996PLC035380                     1996-06-05
# U75112TN1999PLC041764                     1999-01-22
# U85110TN1995PLC033885                     1995-12-18
# U85110TZ1992PLC003742                     1992-04-28
#
#                                                                       COMPANY_NAME  \
# CORPORATE_IDENTIFICATION_NUMBER
# L51909TN1995PLC030554                                    SARASH INDUSTRIES LIMITED
# U01115TN1974SGC006552                 TAMILNADU SUGARCANE FARM CORPORATION LIMITED
# U25209TN1995PLC032313                                              VOX IND LIMITED
# U65991TN1996PLC035380                          RAJAKAMANGALAM BENEFIT FUND LIMITED
# ...

# %%
tn_data.iat[11,1]
# Out:
# 'NEPC TEA GARDEN LIMITED'

# %%
tn_data.at['U85110TN1995PLC033885','COMPANY_NAME']
# Out:
# 'AMERICAN HOSPITALS CORPORATION LIMITED'

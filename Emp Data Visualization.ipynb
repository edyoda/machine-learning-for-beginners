# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# %%
emp_data = pd.read_csv('data/HR_comma_sep.csv')

# %%
emp_data.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales', 'salary'],
#       dtype='object')

# %%
emp_data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
emp_data.rename(columns={'sales':'dept'}, inplace=True)

# %%
emp_data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years   dept  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
emp_data_dept = emp_data.groupby('dept').size()

# %%
emp_data_dept.plot.bar()

# %% [markdown]
# ### Average Monthly Hours for each department

# %%
emp_data_hours = emp_data.groupby('dept').average_montly_hours.mean().sort_values(ascending=True)

# %%
emp_data_hours.plot.barh()

# %%
emp_data_hours.index.tolist()
# Out:
# ['hr',
#  'marketing',
#  'product_mng',
#  'support',
#  'RandD',
#  'sales',
#  'accounting',
#  'management',
#  'IT',
#  'technical']

# %%
emp_data_hours.values
# Out:
# array([ 198.68470907,  199.38578089,  199.96563193,  200.75818753,
#         200.80050826,  200.91135266,  201.16297262,  201.24920635,
#         202.21597392,  202.49742647])

# %%
emp_data.plot.scatter(x='satisfaction_level', y='average_montly_hours')

# %%
emp_data.plot.hexbin(x='satisfaction_level', y='average_montly_hours', gridsize=25)

# %%
emp_data_dept.plot.pie(autopct='%.2f')

# %%
emp_data_hours
# Out:
# dept
# hr             198.684709
# marketing      199.385781
# product_mng    199.965632
# support        200.758188
# RandD          200.800508
# sales          200.911353
# accounting     201.162973
# management     201.249206
# IT             202.215974
# technical      202.497426
# Name: average_montly_hours, dtype: float64

# %%
emp_data_dept
# Out:
# dept
# IT             1227
# RandD           787
# accounting      767
# hr              739
# management      630
# marketing       858
# product_mng     902
# sales          4140
# support        2229
# technical      2720
# dtype: int64

# %%
df = pd.DataFrame({'hrs':emp_data_hours, 'count':emp_data_dept})

# %%
df.plot.pie(subplots=True, figsize=(16,8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001C33D8AA198>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C33E9ACB00>], dtype=object)

# %%
import numpy as np

    
ppl_quit =  emp_data.groupby('number_project').left.apply(lambda x: np.mean(x))

# %%
s = 1 - ppl_quit

# %%
s.plot.bar()

# %%
d = emp_data.groupby(['left','salary']).size()

# %%
d[0]['high']
# Out:
# 1155

# %%
d[0].plot.bar()

# %%
d[1].plot.bar()

# %%
fig, ax = plt.subplots(1, 2)
a = ax[0]
a.set_ylabel('good')
a.set_xticks(ticks=[1,2,3,4,5])
a.set_yticks(ticks=[1,2,3,4,5])
a.text(x=1,s='abc',y=1)

# %%
ax
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001C33EC79668>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C33EF25588>], dtype=object)

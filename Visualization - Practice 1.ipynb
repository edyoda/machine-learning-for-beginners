# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index= pd.date_range('1/1/2000',periods=1000), columns=list('ABCD'))

# %%
df.cumsum().plot()

# %%
df2 = pd.DataFrame(np.random.rand(10,4), columns=['a','b', 'c','d'])

# %%
df2
# Out:
#           a         b         c         d
# 0  0.814249  0.755078  0.488809  0.515580
# 1  0.858575  0.665828  0.457681  0.264615
# 2  0.158164  0.288073  0.456156  0.192076
# 3  0.698365  0.849127  0.618865  0.455203
# 4  0.570271  0.491439  0.510846  0.291529
# 5  0.221075  0.409960  0.765275  0.850829
# 6  0.606147  0.083439  0.584281  0.734391
# 7  0.609618  0.722600  0.066886  0.097002
# 8  0.146378  0.215013  0.192137  0.292527
# 9  0.139007  0.446549  0.564227  0.319277

# %%
df2.T.plot.bar()

# %%
df4 = pd.DataFrame({'a':[1,2,3,4,4,4,4,4,2,4,5,5]})

# %%
df4.plot.hist(alpha=0.5, bins=3,orientation='horizontal')

# %%
df = pd.DataFrame(np.random.rand(10,5), columns=['a','b','c','d','e'])
df.plot.box()

# %%
df.describe()
# Out:
#                a          b          c          d          e
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.473150   0.383437   0.391021   0.633453   0.626168
# std     0.288112   0.349167   0.298530   0.295821   0.327588
# min     0.014977   0.015296   0.036263   0.061384   0.058169
# 25%     0.323186   0.148359   0.173047   0.520174   0.484394
# 50%     0.469168   0.219514   0.310914   0.589887   0.682993
# 75%     0.693199   0.547390   0.610897   0.898250   0.890184
# max     0.946707   0.968968   0.932578   0.975533   0.978680

# %%
df.min()
# Out:
# a    0.014977
# b    0.015296
# c    0.036263
# d    0.061384
# e    0.058169
# dtype: float64

# %%
df.mean()
# Out:
# a    0.473150
# b    0.383437
# c    0.391021
# d    0.633453
# e    0.626168
# dtype: float64

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.355212  0.074930  0.350122  0.292856
# 1  0.023491  0.576510  0.351543  0.360298
# 2  0.418183  0.813777  0.167912  0.319986
# 3  0.392838  0.075708  0.631849  0.494925
# 4  0.441552  0.186004  0.253774  0.209667
# 5  0.273263  0.863564  0.630972  0.419369
# 6  0.928103  0.820359  0.742800  0.949555
# 7  0.192877  0.100656  0.473171  0.883652
# 8  0.801570  0.759432  0.013642  0.950453
# 9  0.703503  0.003944  0.687609  0.887052

# %%
df.plot.area()

# %%
df.plot.area(stacked=False)

# %%
from sklearn.datasets import california_housing

# %%
housing = california_housing.fetch_california_housing()

# %%
housing.data.shape
# Out:
# (20640, 8)

# %%
cities = pd.read_csv('california_cities.csv', index_col='Unnamed: 0')

# %%
import matplotlib.pyplot as plt

# %%
lat, lon = cities['latd'], cities['longd']
population, area = cities['population_total'], cities['area_total_km2']

# %%
plt.scatter(lat, lon, c=np.log10(population), s=area, cmap='viridis')
plt.colorbar(label='log population')

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])

# %%
df['b'] = df['b'] + np.arange(1000)

# %%
df.plot.hexbin(x='a', y='b', gridsize=10)

# %%
df.plot.scatter(x='a',y='b')

# %%
df = pd.DataFrame(3 * np.random.rand(4, 2), index=['a', 'b', 'c', 'd'], columns=['x', 'y'])

# %%
df
# Out:
#           x         y
# a  2.097686  0.796897
# b  1.903311  0.391777
# c  2.765264  1.111873
# d  2.349040  2.071161

# %%
df.plot.pie( 'y', subplots=False, figsize=(12, 3), autopct='%.3f')

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#             a         b         c         d
# 0    0.856640  0.409659 -2.579559  0.282963
# 1    1.160478  1.050277 -0.493590 -2.750647
# 2    1.401262  0.666114  0.783598 -1.271206
# 3   -0.094615  0.061898  1.168447 -1.383054
# 4   -0.289510  0.599966  1.101329 -0.796549
# 5   -0.650388 -0.230205 -0.158200 -1.774427
# 6   -0.434254  0.612607 -1.671251 -1.421979
# 7   -0.666932  1.202244  1.074205 -0.964846
# 8    1.425481  0.543673 -1.237942 -0.803902
# 9   -0.430890  0.998116 -0.270163 -0.241663
# 10  -0.554836  1.452184  1.264190 -1.362769
# 11   0.796932 -1.183591 -2.200547  0.492197
# 12  -0.594376  0.781161 -0.091763 -0.463208
# 13   0.664976 -0.485650 -0.632985  0.093427
# 14  -0.471624 -0.436608 -0.425561 -0.497149
# 15   1.391921  2.345956  0.818006  1.142819
# 16  -0.122708  1.033814  0.526732  0.363299
# 17   1.244767 -0.039810 -1.118753 -1.219633
# 18  -0.437486  0.728348  1.244660  1.283902
# 19   0.336188 -0.851790 -0.500386 -0.333090
# 20  -0.115835 -1.115064  0.516468  0.688030
# 21   0.580529 -0.486767 -0.787434  1.679222
# 22   0.111487 -0.441527 -0.733065  0.494832
# 23  -0.169301 -0.221678  0.249410 -0.400726
# 24   0.180120  1.509784 -0.794868  1.108352
# 25  -1.643864 -1.476534  0.662303 -0.211609
# 26  -1.768887  1.143983 -0.228459  0.459434
# 27   0.493573  0.828827 -1.509580 -0.284846
# 28  -0.635807  0.691217  1.385948  0.669350
# 29  -0.538727 -0.456662  1.438450 -2.150457
# ..        ...       ...       ...       ...
# 970 -0.065709  1.081748  0.419172  1.013806
# 971  1.189383  1.093074  0.410366 -0.258111
# 972  0.282075  1.708498  0.649241 -0.882897
# 973  0.833068 -0.705661  0.863711  0.178069
# 974 -0.706698 -1.021679  0.611289 -0.277243
# 975 -0.762836 -1.330857  0.131347 -1.396147
# 976 -0.578193  1.694127  0.240447 -1.119376
# 977  1.953780 -0.410269  0.454981  1.233152
# 978 -0.004649 -1.074744  0.023245  0.724902
# 979  0.240614 -0.982716 -0.808098 -0.972196
# 980  2.224658 -1.550642  0.708459  0.854465
# 981  1.128606  0.135223 -0.176018  1.421808
# 982  0.515173  0.785348 -1.144398 -3.208115
# 983 -0.191346  0.612499  0.115131 -0.740318
# 984 -0.579172  0.150525 -1.103509 -1.244855
# 985 -0.916593  1.470139  0.332782 -1.405423
# 986 -0.675600  0.497173 -0.142277  0.167836
# 987 -0.783016 -0.526848  1.732366 -2.767866
# 988 -0.238568  1.141814 -0.362454 -1.082459
# 989 -0.510275 -0.162395 -0.491158 -0.797909
# 990 -1.000861 -1.309526  0.690307 -0.776230
# 991  0.087975  0.034153 -0.479873  0.863202
# 992 -0.102888  1.698254  0.695980 -0.738915
# 993  1.846331  0.948026  1.396209  0.394506
# 994 -1.031171 -0.415194  0.496252 -0.973840
# 995 -0.273072 -0.179463  0.194368  0.039316
# 996  0.744158  1.189714 -0.601264 -2.229651
# 997 -0.678160 -1.719788 -0.011342  0.437390
# 998  0.896991  0.986296  0.117348 -0.409840
# 999  1.606854  1.651087 -1.890032  1.201213
#
# [1000 rows x 4 columns]

# %%
df.plot(subplots=True, figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001F33943ABE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001F339505278>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001F3394D1048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001F3395983C8>], dtype=object)

# %%
from sklearn.datasets import load_digits

# %%
data = load_digits()

# %%
plt.imshow(data.data[0].reshape(8,8), cmap='gray')

# %%
plt.imshow(data.data[1].reshape(8,8), cmap='gray')

# %%
data.data[1].reshape(8,8)
# Out:
# array([[  0.,   0.,   0.,  12.,  13.,   5.,   0.,   0.],
#        [  0.,   0.,   0.,  11.,  16.,   9.,   0.,   0.],
#        [  0.,   0.,   3.,  15.,  16.,   6.,   0.,   0.],
#        [  0.,   7.,  15.,  16.,  16.,   2.,   0.,   0.],
#        [  0.,   0.,   1.,  16.,  16.,   3.,   0.,   0.],
#        [  0.,   0.,   1.,  16.,  16.,   6.,   0.,   0.],
#        [  0.,   0.,   1.,  16.,  16.,   6.,   0.,   0.],
#        [  0.,   0.,   0.,  11.,  16.,  10.,   0.,   0.]])

# %%
from skimage.io import imread

# %%
cat = imread('cat.jpg')

# %%
cat.shape
# Out:
# (79, 93, 3)

# %%
plt.imshow(cat)

# %%
fig = plt.figure(figsize=(10,10))
fig.subplots_adjust(hspace=0.1, wspace=0.4)
for i in range(1,7):
    ax = fig.add_subplot(2,3,i)
    ax.text(0.5,0.5, "good")
    plt.xticks(np.arange(5), ('T', 'D', 'H', 'S', 'S'))

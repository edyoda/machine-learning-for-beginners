# %%
import pandas as pd

# %%
df = pd.DataFrame({'A':[1,2,3,4,5], 'B':[5,6,7,8,9]})

# %%
df
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8
# 4  5  9

# %%
df.add(5)
# Out:
#     A   B
# 0   6  10
# 1   7  11
# 2   8  12
# 3   9  13
# 4  10  14

# %%
df.add(df)
# Out:
#     A   B
# 0   2  10
# 1   4  12
# 2   6  14
# 3   8  16
# 4  10  18

# %% [markdown]
# ### Concatenating DataFrames
# * Row wise combining of data

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3'],
                     'C': ['C0', 'C1', 'C2', 'C3'],
                     'D': ['D0', 'D1', 'D2', 'D3']},
                     index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'],
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    )

# %%
frames = [df1, df2, df3]

# %%
pd.concat(frames)
# Out:
#      A    B    C    D
# 0   A0   B0   C0   D0
# 1   A1   B1   C1   D1
# 2   A2   B2   C2   D2
# 3   A3   B3   C3   D3
# 4   A4   B4   C4   D4
# 5   A5   B5   C5   D5
# 6   A6   B6   C6   D6
# 7   A7   B7   C7   D7
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
pd.concat(frames, ignore_index=True)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df4 = pd.concat(frames, keys=['x','y','z'])

# %%
df4
# Out:
#        A    B    C    D
# x 0   A0   B0   C0   D0
#   1   A1   B1   C1   D1
#   2   A2   B2   C2   D2
#   3   A3   B3   C3   D3
# y 4   A4   B4   C4   D4
#   5   A5   B5   C5   D5
#   6   A6   B6   C6   D6
#   7   A7   B7   C7   D7
# z 0   A8   B8   C8   D8
#   1   A9   B9   C9   D9
#   2  A10  B10  C10  D10
#   3  A11  B11  C11  D11

# %%
df4.loc['y',5]
# Out:
# A    A5
# B    B5
# C    C5
# D    D5
# Name: (y, 5), dtype: object

# %%
df4.loc['y': 'z']
# Out:
#         A    B    C    D
# y 4    A4   B4   C4   D4
#   5    A5   B5   C5   D5
#   6    A6   B6   C6   D6
#   7    A7   B7   C7   D7
# z 7    A8   B8   C8   D8
#   9    A9   B9   C9   D9
#   10  A10  B10  C10  D10
#   11  A11  B11  C11  D11

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                     'D': ['D2', 'D3', 'D6', 'D7'],
                     'F': ['F2', 'F3', 'F6', 'F7']},
                    index=[2, 3, 6, 7])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
pd.concat([df1, df4], axis=1)
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
pd.concat([df1, df4], axis=1, join='inner')
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# ### Concatenating using append

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df1.append(df2)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df1.append([df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 7    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df1.append([df2,df3], ignore_index=True)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ### Concatenating with mixed ndims

# %%
s1 = pd.Series(['X0', 'X1', 'X2', 'X3'])

# %%
s1
# Out:
# 0    X0
# 1    X1
# 2    X2
# 3    X3
# dtype: object

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
pd.concat([df1,s1], axis=1)
# Out:
#     A   B   C   D   0
# 0  A0  B0  C0  D0  X0
# 1  A1  B1  C1  D1  X1
# 2  A2  B2  C2  D2  X2
# 3  A3  B3  C3  D3  X3

# %% [markdown]
# ### Unnamed Series

# %%
s2 = pd.Series(['_0', '_1', '_2', '_3'])

# %%
pd.concat([df1,s2, s2], axis=1, ignore_index=True)
# Out:
#     0   1   2   3   4   5
# 0  A0  B0  C0  D0  _0  _0
# 1  A1  B1  C1  D1  _1  _1
# 2  A2  B2  C2  D2  _2  _2
# 3  A3  B3  C3  D3  _3  _3

# %% [markdown]
# #### Databae-style DataFrame joining/merging
# * hugh performance in-memory join operations
# * merge

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                         'A': ['A0', 'A1', 'A2', 'A3'],
                         'B': ['B0', 'B1', 'B2', 'B3']})

right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                         'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#     A   B key
# 0  A0  B0  K0
# 1  A1  B1  K1
# 2  A2  B2  K2
# 3  A3  B3  K3

# %%
right
# Out:
#     C   D key
# 0  C0  D0  K0
# 1  C1  D1  K1
# 2  C2  D2  K2
# 3  C3  D3  K3

# %%
pd.merge(left,right,on='key')
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K2  C2  D2
# 3  A3  B3  K3  C3  D3

# %%
left = pd.DataFrame({ 'key1': ['K0', 'K0', 'K1', 'K2'],
                      'key2': ['K0', 'K1', 'K0', 'K1'],
                         'A': ['A0', 'A1', 'A2', 'A3'],
                         'B': ['B0', 'B1', 'B2', 'B3']})
    

right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0'],
                      'C':    ['C0', 'C1', 'C2', 'C3'],
                         'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(left, right, how= 'right', on=['key1','key2'])
# Out:
#      A    B key1 key2   C   D
# 0   A0   B0   K0   K0  C0  D0
# 1   A2   B2   K1   K0  C1  D1
# 2   A2   B2   K1   K0  C2  D2
# 3  NaN  NaN   K2   K0  C3  D3

# %% [markdown]
# ### Handling duplicates

# %%
left = pd.DataFrame({'A' : [1,2], 'B' : [1, 2]})

# %%
right = pd.DataFrame({'A' : [4,5,6], 'B': [2, 2, 2]})

# %%
pd.merge(left, right, on='B', how='outer')
# Out:
#    A_x  B  A_y
# 0    1  1  NaN
# 1    2  2  4.0
# 2    2  2  5.0
# 3    2  2  6.0

# %%
left
# Out:
#    A  B
# 0  1  1
# 1  2  2

# %%
right
# Out:
#    A  B
# 0  4  2
# 1  5  2
# 2  6  2

# %%
#pd.merge(left, right, on='B', how='outer', validate="one_to_many")

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left, right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False)
#     Merge DataFrame objects by performing a database-style join operation by
#     columns or indexes.
#
#     If joining columns on columns, the DataFrame indexes *will be
#     ignored*. Otherwise if joining indexes on indexes or indexes on a column or
#     columns, the index will be passed on.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         * left: use only keys from left frame, similar to a SQL left outer join;
#           preserve key order
#         * right: use only keys from right frame, similar to a SQL right outer join;
#           preserve key order
#         * outer: use union of keys from both frames, similar to a SQL full outer
# ...

# %%
pd.__version__
# Out:
# '0.20.3'

# %% [markdown]
# #### merge indicator
# * Show how the merge is happening

# %%
df1 = pd.DataFrame({'col1': [0, 1], 'col_left':['a', 'b']})
df2 = pd.DataFrame({'col1': [1, 2, 2],'col_right':[2, 2, 2]})

# %%
pd.merge(df1, df2, on='col1', how='outer', indicator=True)
# Out:
#    col1 col_left  col_right      _merge
# 0     0        a        NaN   left_only
# 1     1        b        2.0        both
# 2     2      NaN        2.0  right_only
# 3     2      NaN        2.0  right_only

# %% [markdown]
# #### Join by Index

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                     index=['K0', 'K1', 'K2'])

# %%
right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                      'D': ['D0', 'D2', 'D3']},
                     index=['K0', 'K2', 'K3'])

# %%
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
pd.merge(left, right, left_index=True, right_index=True, how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
left.join([right], how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
pd.merge(left, right, how='outer', left_on='A' , right_on='D' )
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3  NaN  NaN   C0   D0
# 4  NaN  NaN   C2   D2
# 5  NaN  NaN   C3   D3

# %% [markdown]
# ### Joining multiple Dataframe or Panel objects

# %%
right2 = pd.DataFrame({'v': [7, 8, 9]}, index=['K1', 'K1', 'K2'])

# %%
right2
# Out:
#     v
# K1  7
# K1  8
# K2  9

# %%
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
left.join([right, right2])
# Out:
#       A    B    C    D    v
# K0   A0   B0   C0   D0  NaN
# K1   A1   B1  NaN  NaN  7.0
# K1   A1   B1  NaN  NaN  8.0
# K2   A2   B2   C2   D2  9.0
# K3  NaN  NaN   C3   D3  NaN

# %% [markdown]
# ### merge_asof
# * similar to an ordered left-join except that we match nearest key rather than equal keys

# %%
trades = pd.DataFrame({
        'time': pd.to_datetime(['20160525 13:30:00.023',
                                '20160525 13:30:00.038',
                                '20160525 13:30:00.048',
                                '20160525 13:30:00.048',
                                '20160525 13:30:00.048']),
        'ticker': ['MSFT', 'MSFT',
                  'GOOG', 'GOOG', 'AAPL'],
       'price': [51.95, 51.95,
                  720.77, 720.92, 98.00],
        'quantity': [75, 155,
                     100, 100, 100]},
        columns=['time', 'ticker', 'price', 'quantity'])

# %%
trades
# Out:
#                      time ticker   price  quantity
# 0 2016-05-25 13:30:00.023   MSFT   51.95        75
# 1 2016-05-25 13:30:00.038   MSFT   51.95       155
# 2 2016-05-25 13:30:00.048   GOOG  720.77       100
# 3 2016-05-25 13:30:00.048   GOOG  720.92       100
# 4 2016-05-25 13:30:00.048   AAPL   98.00       100

# %%
quotes = pd.DataFrame({
        'time': pd.to_datetime(['20160525 13:30:00.023',
                                '20160525 13:30:00.023',
                                '20160525 13:30:00.030',
                                '20160525 13:30:00.041',
                                '20160525 13:30:00.045',
                                '20160525 13:30:00.046',
                                '20160525 13:30:00.072',
                                '20160525 13:30:00.075']),
        'ticker': ['GOOG', 'MSFT', 'MSFT',
                   'MSFT', 'GOOG', 'AAPL', 'GOOG',
                   'MSFT'],
        'bid': [720.50, 51.95, 51.97, 51.99,
                720.50, 97.99, 720.50, 52.01],
        'ask': [720.93, 51.96, 51.98, 52.00,
                720.93, 98.01, 720.88, 52.03]},
        columns=['time', 'ticker', 'bid', 'ask'])

# %%
quotes
# Out:
#                      time ticker     bid     ask
# 0 2016-05-25 13:30:00.023   GOOG  720.50  720.93
# 1 2016-05-25 13:30:00.023   MSFT   51.95   51.96
# 2 2016-05-25 13:30:00.030   MSFT   51.97   51.98
# 3 2016-05-25 13:30:00.041   MSFT   51.99   52.00
# 4 2016-05-25 13:30:00.045   GOOG  720.50  720.93
# 5 2016-05-25 13:30:00.046   AAPL   97.99   98.01
# 6 2016-05-25 13:30:00.072   GOOG  720.50  720.88
# 7 2016-05-25 13:30:00.075   MSFT   52.01   52.03

# %%
pd.merge_asof(trades, quotes, on='time', by='ticker', tolerance=pd.Timedelta('10ms'))
# Out:
#                      time ticker   price  quantity     bid     ask
# 0 2016-05-25 13:30:00.023   MSFT   51.95        75   51.95   51.96
# 1 2016-05-25 13:30:00.038   MSFT   51.95       155   51.97   51.98
# 2 2016-05-25 13:30:00.048   GOOG  720.77       100  720.50  720.93
# 3 2016-05-25 13:30:00.048   GOOG  720.92       100  720.50  720.93
# 4 2016-05-25 13:30:00.048   AAPL   98.00       100   97.99   98.01

# %%
sales_data = pd.read_csv('data/rossmansales/train.csv/rossmann-train.csv')
# Out:
# C:\Users\ZekeLabs\Anaconda3-N\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
store_data = pd.read_csv('data/rossmansales/store.csv/store.csv')

# %%
store_data.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
sales_data.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
# Store            1017209 non-null int64
# DayOfWeek        1017209 non-null int64
# Date             1017209 non-null object
# Sales            1017209 non-null int64
# Customers        1017209 non-null int64
# Open             1017209 non-null int64
# Promo            1017209 non-null int64
# StateHoliday     1017209 non-null object
# SchoolHoliday    1017209 non-null int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %%
store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
# Store                        1115 non-null int64
# StoreType                    1115 non-null object
# Assortment                   1115 non-null object
# CompetitionDistance          1112 non-null float64
# CompetitionOpenSinceMonth    761 non-null float64
# CompetitionOpenSinceYear     761 non-null float64
# Promo2                       1115 non-null int64
# Promo2SinceWeek              571 non-null float64
# Promo2SinceYear              571 non-null float64
# PromoInterval                571 non-null object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
store_sales = pd.merge(store_data,sales_data)

# %%
store_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
# Store                        1017209 non-null int64
# StoreType                    1017209 non-null object
# Assortment                   1017209 non-null object
# CompetitionDistance          1014567 non-null float64
# CompetitionOpenSinceMonth    693861 non-null float64
# CompetitionOpenSinceYear     693861 non-null float64
# Promo2                       1017209 non-null int64
# Promo2SinceWeek              509178 non-null float64
# Promo2SinceYear              509178 non-null float64
# PromoInterval                509178 non-null object
# DayOfWeek                    1017209 non-null int64
# Date                         1017209 non-null object
# Sales                        1017209 non-null int64
# Customers                    1017209 non-null int64
# Open                         1017209 non-null int64
# Promo                        1017209 non-null int64
# ...

# %%
store_sales.Open.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
store_sales.DayOfWeekOfWeek.unique()
# Out:
# array([5, 4, 3, 2, 1, 7, 6], dtype=int64)

# %%
store_sales.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      1         c          a               1270.0                        9.0
# 2      1         c          a               1270.0                        9.0
# 3      1         c          a               1270.0                        9.0
# 4      1         c          a               1270.0                        9.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2008.0       0              NaN              NaN
# 2                    2008.0       0              NaN              NaN
# 3                    2008.0       0              NaN              NaN
# 4                    2008.0       0              NaN              NaN
#
#   PromoInterval  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# ...
